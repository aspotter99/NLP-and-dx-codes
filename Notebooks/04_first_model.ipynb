# %%
#Building the first simple model 

import sqlite3 as sl
import pandas as pd

# %%
conn = sl.connect('../Data/patient_data.db')
c = conn.cursor()

# %%
res = conn.execute("SELECT name FROM sqlite_master WHERE type='table';")
for name in res:
    print (name[0])
# Out:
# ADMISSIONS
# CALLOUT
# CPTEVENTS
# DX_ICD
# D_CPT
# DRGCODES
# ICUSTAY
# NOTES
# PATIENTS
# SERVICES
# DRG

# %%
df = pd.read_sql('''SELECT * from admissions limit 10;''',conn)
df
# Out:
#    SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
# 5          26   197661  2126-05-06 15:16:00  2126-05-13 15:00:00
# 6          27   134931  2191-11-30 22:16:00  2191-12-03 14:45:00
# 7          28   162569  2177-09-01 07:15:00  2177-09-06 16:00:00
# 8          30   104557  2172-10-14 14:17:00  2172-10-19 14:37:00
# 9          31   128652  2108-08-22 23:27:00  2108-08-30 15:00:00
#
#              DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0                 None      EMERGENCY       EMERGENCY ROOM ADMIT
# 1                 None       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# ...

# %%
df = pd.read_sql('''SELECT * from notes limit 10;''', conn)

# %%
df
# Out:
#    SUBJECT_ID   HADM_ID   CHARTDATE CHARTTIME STORETIME           CATEGORY  \
# 0       22532  167853.0  2151-08-04      None      None  Discharge summary
# 1       13702  107527.0  2118-06-14      None      None  Discharge summary
# 2       13702  167118.0  2119-05-25      None      None  Discharge summary
# 3       13702  196489.0  2124-08-18      None      None  Discharge summary
# 4       26880  135453.0  2162-03-25      None      None  Discharge summary
# 5       53181  170490.0  2172-03-08      None      None  Discharge summary
# 6       20646  134727.0  2112-12-10      None      None  Discharge summary
# 7       42130  114236.0  2150-03-01      None      None  Discharge summary
# 8       56174  163469.0  2118-08-12      None      None  Discharge summary
# 9       56174  189681.0  2118-12-09      None      None  Discharge summary
#
#   DESCRIPTION  CGID ISERROR                                               TEXT
# ...

# %%
df = pd.read_sql('''select * from patients limit 10;''',conn)
df
# Out:
#    SUBJECT_ID GENDER                  DOB                  DOD  \
# 0         249      F  2075-03-13 00:00:00                 None
# 1         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2         251      M  2090-03-15 00:00:00                 None
# 3         252      M  2078-03-06 00:00:00                 None
# 4         253      F  2089-11-26 00:00:00                 None
# 5         255      M  2109-08-05 00:00:00                 None
# 6         256      M  2086-07-31 00:00:00                 None
# 7         257      F  2031-04-03 00:00:00  2121-07-08 00:00:00
# 8         258      F  2124-09-19 00:00:00                 None
# 9         260      F  2105-03-23 00:00:00                 None
#
#               DOD_HOSP              DOD_SSN  EXPIRE_FLAG
# 0                 None                 None            0
# 1  2188-11-22 00:00:00                 None            1
# 2                 None                 None            0
# ...

# %%
diag = pd.read_sql('''select distinct DIAGNOSIS from admissions;''',conn)
diag
# Out:
#                                                DIAGNOSIS
# 0                                BENZODIAZEPINE OVERDOSE
# 1      CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...
# 2                                             BRAIN MASS
# 3                         INTERIOR MYOCARDIAL INFARCTION
# 4                                ACUTE CORONARY SYNDROME
# ...                                                  ...
# 15687                       RIGHT URETERAL STRICTURE/SDA
# 15688                 BILATERAL URETERAL OBSTRUCTION/SDA
# 15689                                     R/O METASTASIS
# 15690  GASTROPARESIS\PLACEMENT OF G-TUBE **REMOTE WES...
# 15691                                     JOINT EFFUSION
#
# [15692 rows x 1 columns]

# %%
benzo = pd.read_sql('''select * from admissions where diagnosis == 'BENZODIAZEPINE OVERDOSE' order by subject_id desc;''',conn)
benzo
# Out:
#    SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME DEATHTIME  \
# 0        4103   162155  2139-06-14 15:37:00  2139-06-16 20:37:00      None
# 1          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00      None
#
#   ADMISSION_TYPE    ADMISSION_LOCATION         DISCHARGE_LOCATION INSURANCE  \
# 0      EMERGENCY  EMERGENCY ROOM ADMIT   DISCH-TRAN TO PSYCH HOSP  Medicare
# 1      EMERGENCY  EMERGENCY ROOM ADMIT  DISC-TRAN CANCER/CHLDRN H   Private
#
#   LANGUAGE      RELIGION MARITAL_STATUS ETHNICITY            EDREGTIME  \
# 0     ENGL         OTHER        MARRIED     WHITE  2139-06-14 12:48:00
# 1     None  UNOBTAINABLE        MARRIED     WHITE  2196-04-09 10:06:00
#
#              EDOUTTIME                DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0  2139-06-14 16:50:00  BENZODIAZEPINE OVERDOSE                     0
# 1  2196-04-09 13:24:00  BENZODIAZEPINE OVERDOSE                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1

# %%
diag = pd.read_sql('''select diagnosis, count(*) from admissions group by diagnosis order by count(*) desc limit 10;''',conn)
diag
# Out:
#                                            DIAGNOSIS  count(*)
# 0                                            NEWBORN      7823
# 1                                          PNEUMONIA      1566
# 2                                             SEPSIS      1184
# 3                           CONGESTIVE HEART FAILURE       928
# 4                            CORONARY ARTERY DISEASE       840
# 5                                         CHEST PAIN       778
# 6                            INTRACRANIAL HEMORRHAGE       713
# 7                              ALTERED MENTAL STATUS       712
# 8                             GASTROINTESTINAL BLEED       686
# 9  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...       583

# %%
#from the query above, it looks like we have a few diagnoses we can use for a first simple model -- I am going to use Gastrointestinal bleed
#and intracranial hemorrhage, these are diagnoses that are fairly evenly distributed (686 and 713) so class imbalance should not be a problem

data = pd.read_sql('''select * from admissions where diagnosis in ('GASTROINTESTINAL BLEED','INTRACRANIAL HEMORRHAGE') order by subject_id;''',conn)

# %%
data
# Out:
#       SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0             46   144073  2133-02-20 18:21:00  2133-02-24 14:42:00
# 1            112   174105  2194-06-13 18:39:00  2194-06-18 16:50:00
# 2            158   169433  2170-02-03 11:38:00  2170-02-06 16:49:00
# 3            186   164405  2176-09-25 23:13:00  2176-10-01 19:20:00
# 4            212   189635  2189-11-07 21:35:00  2189-11-10 17:00:00
# ...          ...      ...                  ...                  ...
# 1394       98948   125469  2136-10-21 14:26:00  2136-10-29 20:10:00
# 1395       99183   184631  2157-03-01 18:49:00  2157-03-04 16:22:00
# 1396       99184   171203  2193-12-16 21:53:00  2193-12-19 16:55:00
# 1397       99366   136021  2197-03-20 23:57:00  2197-05-18 13:38:00
# 1398       99562   129689  2183-02-02 15:13:00  2183-02-18 13:28:00
#
#                 DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0                    None      EMERGENCY  CLINIC REFERRAL/PREMATURE
# ...

# %%
notes = pd.read_sql('''select * from notes limit 10;''',conn)
notes
# Out:
#    SUBJECT_ID   HADM_ID   CHARTDATE CHARTTIME STORETIME           CATEGORY  \
# 0       22532  167853.0  2151-08-04      None      None  Discharge summary
# 1       13702  107527.0  2118-06-14      None      None  Discharge summary
# 2       13702  167118.0  2119-05-25      None      None  Discharge summary
# 3       13702  196489.0  2124-08-18      None      None  Discharge summary
# 4       26880  135453.0  2162-03-25      None      None  Discharge summary
# 5       53181  170490.0  2172-03-08      None      None  Discharge summary
# 6       20646  134727.0  2112-12-10      None      None  Discharge summary
# 7       42130  114236.0  2150-03-01      None      None  Discharge summary
# 8       56174  163469.0  2118-08-12      None      None  Discharge summary
# 9       56174  189681.0  2118-12-09      None      None  Discharge summary
#
#   DESCRIPTION  CGID ISERROR                                               TEXT
# ...

# %%
text = pd.read_sql('''select * from notes where subject_id = 112 AND hadm_id = '174105';''',conn)
text
# Out:
#    SUBJECT_ID   HADM_ID   CHARTDATE            CHARTTIME            STORETIME  \
# 0         112  174105.0  2194-06-18                 None                 None
# 1         112  174105.0  2194-06-16                 None                 None
# 2         112  174105.0  2194-06-16                 None                 None
# 3         112  174105.0  2194-06-14                 None                 None
# 4         112  174105.0  2194-06-13                 None                 None
# 5         112  174105.0  2194-06-13                 None                 None
# 6         112  174105.0  2194-06-14  2194-06-14 04:55:00  2194-06-14 05:15:00
#
#             CATEGORY DESCRIPTION     CGID ISERROR  \
# 0  Discharge summary      Report      NaN    None
# 1                ECG      Report      NaN    None
# 2                ECG      Report      NaN    None
# 3                ECG      Report      NaN    None
# 4                ECG      Report      NaN    None
# ...

# %%
#there are quite a few different note types, for this first pass we will onlhy look at Nursing/other and Discharge summary.

data = pd.read_sql("""
                   SELECT adm.subject_id, 
                          adm.hadm_id,
                          admission_type,
                          admission_location,
                          notes.chartdate,
                          notes.charttime,
                          notes.category,
                          notes.description,
                          notes.iserror,
                          notes.text,
                          adm.diagnosis
                    FROM admissions as adm
                    JOIN notes on adm.subject_id = notes.subject_id
                         AND adm.hadm_id = notes.hadm_id
                    WHERE adm.diagnosis in ('GASTROINTESTINAL BLEED','INTRACRANIAL HEMORRHAGE') 
                         AND category in ('Nursing/other','Discharge summary')
                    ORDER BY adm.subject_id, adm.hadm_id, chartdate""",conn)
data.to_csv('../Data/first_model_data.csv')
data
# Out:
#        SUBJECT_ID  HADM_ID ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0              46   144073      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 1              46   144073      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 2             112   174105      EMERGENCY       EMERGENCY ROOM ADMIT
# 3             112   174105      EMERGENCY       EMERGENCY ROOM ADMIT
# 4             158   169433      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# ...           ...      ...            ...                        ...
# 11682       98948   125469      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 11683       99183   184631      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 11684       99184   171203      EMERGENCY       EMERGENCY ROOM ADMIT
# 11685       99366   136021      EMERGENCY  CLINIC REFERRAL/PREMATURE
# 11686       99562   129689         URGENT  TRANSFER FROM HOSP/EXTRAM
#
#         CHARTDATE            CHARTTIME           CATEGORY DESCRIPTION ISERROR  \
# ...

# %%
# Standard imports
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Model selection
from sklearn.model_selection import train_test_split

# Preprocessing
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import string
import unicodedata
import nltk
from nltk.tokenize import regexp_tokenize, word_tokenize, RegexpTokenizer, WhitespaceTokenizer
from nltk.corpus import stopwords, wordnet
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer 
from textblob import TextBlob
import re

# Models
from sklearn.naive_bayes import MultinomialNB

# Metrics
from sklearn.metrics import accuracy_score, recall_score, precision_score, confusion_matrix, make_scorer

# additional viz
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
import PIL.ImageOps

#.py file
import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)
#import src.functions as asp

np.random.seed(42)
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
from nltk.corpus import stopwords
sw = stopwords.words('english')

def get_wordnet_pos(treebank_tag):
    '''
    Translate nltk POS to wordnet tags
    '''
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
    
def doc_preparer(doc, stop_words=sw):
    '''  
    :param doc: a document from the corpus 
    :return: a document string with words which have been 
            lemmatized, 
            parsed for stopwords, 
            made lowercase,
            and stripped of punctuation and numbers.
    '''
    
    regex_token = RegexpTokenizer(r"([a-zA-Z]+(?:’[a-z]+)?)")
    doc = regex_token.tokenize(doc)
    doc = [word.lower() for word in doc]
    doc = [word for word in doc if word not in stop_words]
    doc = pos_tag(doc)
    doc = [(word[0], get_wordnet_pos(word[1])) for word in doc]
    lemmatizer = WordNetLemmatizer() 
    doc = [lemmatizer.lemmatize(word[0], word[1]) for word in doc]
    return ' '.join(doc)

#Preprocess text data and train/test split 

X = data.TEXT.astype('str')
y = data.DIAGNOSIS.astype('str')

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42, test_size=.25)

token_docs = [doc_preparer(doc, sw) for doc in X_train]
token_docs[0]
# Out:
# 'neuro pt remain pleasant good historian pr c arithitic pain receive tylenol mg desire effect reach within min pt remain afebrile time neuro deficit note cv pt begin hr shift drop sbp hr occ pac pt fill ileostomy time loose maroon stool pt give bolus cc n quickly respond return baseline regard v pt drop hct pt receive two unit prbc take red tag study intervention take place hct rechecked follow scan result two hr later pt drop sbp pt c burn sensation upper abd denies c p sob h r occ pac pt respond cc n bolus return baseline v hct send reconfirm result hct pt since receive three additional unit micu intern resident pt bedside observe pt output total cc frothy maroon brown liquid maroon red ace inhibitor presently hold g team notify resp pt remain clear lung sound field c sob resp rate remain regular continue monitor closely pt receive multiple bolus blood transfusion gu gi pt remain npo time abd remain soft non tender bowel sound easily audible ileostomy bag change without difficulty 
# ...

# %%
# Validation train-test split to build our best model
X_t, X_val, y_t, y_val = train_test_split(token_docs, y_train, test_size=.25, random_state=42)

cv = CountVectorizer(max_df=250,max_features=500)

X_t_vec = cv.fit_transform(X_t)
X_t_vec  = pd.DataFrame.sparse.from_spmatrix(X_t_vec)
X_t_vec.columns = sorted(cv.vocabulary_)
X_t_vec.set_index(y_t.index, inplace=True)
X_t_vec
# Out:
#        abgs  abnormal  abnormality  abuse  acid  acidosis  add  addition  \
# 9493      0         0            0      0     0         0    0         0
# 10392     0         0            0      0     0         0    1         0
# 9928      0         0            0      0     0         0    0         0
# 10755     0         0            0      0     0         0    0         0
# 9865      0         0            0      0     0         0    0         0
# ...     ...       ...          ...    ...   ...       ...  ...       ...
# 11329     0         0            1      0     0         0    0         1
# 1538      0         0            0      0     0         0    0         0
# 9806      0         0            0      0     0         0    0         0
# 5079      0         0            0      0     0         0    0         0
# 10522     0         0            0      0     0         0    0         0
#
#        address  administer  ...  withdrawal  withdraws  woman  word  wound  \
# ...

# %%
mnb = MultinomialNB()
mnb.fit(X_t_vec, y_t)
prior_0 = y_t.value_counts()['GASTROINTESTINAL BLEED']/len(y_t)
prior_1 = y_t.value_counts()['INTRACRANIAL HEMORRHAGE']/len(y_t)

print(prior_0, prior_1)
print(np.log(prior_1))
# Out:
# 0.5586490187129165 0.4413509812870835
# -0.8179148441421723

# %%
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix

y_hat = mnb.predict(X_t_vec)
print(accuracy_score(y_t, y_hat))
print(confusion_matrix(y_t,y_hat))
# Out:
# 0.7664688878746386
# [[3384  288]
#  [1247 1654]]

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):

    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()
    
plot_confusion_matrix(cm = np.array(confusion_matrix(y_t,y_hat)), 
                      normalize    = True,
                      target_names = ['GASTROINTESTINAL BLEED','INTRACRANIAL HEMORRHAGE'],
                      title        = "Confusion Matrix")

plt.savefig('../Reports/images/ConfMat_FSM.png')

# %% [markdown]
# not too bad for a first attempt!  this model is pretty good at finding gastrointestinal bleeds, but not as good at intracranial hemmorhage.

# %% [markdown]
# Let's see if using Tfidf Vectorizer can improve our first pass

# %%
# Validation train-test split to build our best model
X_t, X_val, y_t, y_val = train_test_split(token_docs, y_train, test_size=.25, random_state=42)

tfidf = TfidfVectorizer(max_df=250,max_features=500)

X_t_vec = tfidf.fit_transform(X_t)
X_t_vec  = pd.DataFrame.sparse.from_spmatrix(X_t_vec)
X_t_vec.columns = sorted(cv.vocabulary_)
X_t_vec.set_index(y_t.index, inplace=True)
X_t_vec
# Out:
#        abgs  abnormal  abnormality  abuse  acid  acidosis       add  addition  \
# 9493    0.0       0.0     0.000000    0.0   0.0       0.0  0.000000  0.000000
# 10392   0.0       0.0     0.000000    0.0   0.0       0.0  0.577147  0.000000
# 9928    0.0       0.0     0.000000    0.0   0.0       0.0  0.000000  0.000000
# 10755   0.0       0.0     0.000000    0.0   0.0       0.0  0.000000  0.000000
# 9865    0.0       0.0     0.000000    0.0   0.0       0.0  0.000000  0.000000
# ...     ...       ...          ...    ...   ...       ...       ...       ...
# 11329   0.0       0.0     0.049992    0.0   0.0       0.0  0.000000  0.050719
# 1538    0.0       0.0     0.000000    0.0   0.0       0.0  0.000000  0.000000
# 9806    0.0       0.0     0.000000    0.0   0.0       0.0  0.000000  0.000000
# 5079    0.0       0.0     0.000000    0.0   0.0       0.0  0.000000  0.000000
# 10522   0.0       0.0     0.000000    0.0   0.0       0.0  0.000000  0.000000
#
# ...

# %%
mnb = MultinomialNB()
mnb.fit(X_t_vec, y_t)
prior_0 = y_t.value_counts()['GASTROINTESTINAL BLEED']/len(y_t)
prior_1 = y_t.value_counts()['INTRACRANIAL HEMORRHAGE']/len(y_t)

print(prior_0, prior_1)
print(np.log(prior_1))
# Out:
# 0.5586490187129165 0.4413509812870835
# -0.8179148441421723

# %%
y_hat = mnb.predict(X_t_vec)
print(accuracy_score(y_t, y_hat))
print(confusion_matrix(y_t,y_hat))
# Out:
# 0.786855317206755
# [[3297  375]
#  [1026 1875]]

# %%
plot_confusion_matrix(cm = np.array(confusion_matrix(y_t,y_hat)), 
                      normalize    = True,
                      target_names = ['GASTROINTESTINAL BLEED','INTRACRANIAL HEMORRHAGE'],
                      title        = "TfIdf Vectorizer Confusion Matrix")

plt.savefig('../Reports/images/ConfMat_FSM_tfidf.png')

# %% [markdown]
# slight improvement in our model accuracy with a different vectorizer.  hoever, it appears that the tfidf vectorizer is better at intracranial hemmorhage then the count vectorizer model at the expense of gastrointestinal bleeds.
